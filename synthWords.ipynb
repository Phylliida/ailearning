# %%
f = open("bncsplitwords.txt", "r")
text = f.read()
f.close()

# %%
words = set(text.split())

# %%
from collections import Counter
counts = list(Counter(text.split()).items())
counts.sort(key=lambda x: -x[1])
counts
data =
# Out:
# 14935

# %%
# Out:
# Counter({'You': 2334,
#          'enjoyed': 32,
#          'yourself': 109,
#          'in': 7473,
#          'America': 29,
#          'Eh': 193,
#          'did': 1310,
#          'you': 16362,
#          'Oh': 4777,
#          'I': 21053,
#          'covered': 31,
#          'a': 12654,
#          'nice': 649,
#          'trip': 45,
#          'yes': 1035,
#          'very': 905,
#          'good': 983,
#          'saw': 167,
#          'Mary': 37,
#          'and': 12409,
#          'Andrew': 28,
#          'Yes': 1761,
#          'fact': 115,
#          'the': 17888,
#          'whole': 137,
#          'family': 47,
#          'was': 4600,
#          'together': 147,
#          'for': 3965,
#          "Mary's": 5,
#          'wedding': 53,
#          "It's": 1609,
#          'horrible': 56,
#          'It': 915,
#          'is': 4058,
#          "isn't": 585,
#          'Have': 423,
#          'been': 1290,
#          'busy': 60,
#          'oh': 1328,
#          "Jim's": 28,
# ...
